# %% [markdown]
# # Short-Term Memory

# %%
from agents import Agent, Runner, SQLiteSession, trace
from setup import bedrock_tool
# Out:
# ✅ AWS credentials found
# ✅ OpenAI credentials found
# ✅ EXA credentials found

# %%
nutrition_agent = Agent(
    name="Nutrition Assistant",
    instructions="""
    You are a helpful assistant comparing how healthy different foods are.
    If you answer, give a list of how healthy the foods are with a score from 1 to 10. Order by: healtiest food comes first.

    Example:
    Q: Compare X and Y
    A: X is healtier as Y.
    1) X: 8/10 - Very healthy but high in fructose
    2) Y: 3/10 - High in sugar and fat
    """,
    model="litellm/bedrock/eu.amazon.nova-lite-v1:0",
)

# %% [markdown]
# ## No Memory

# %%
with trace("Compare without Memory") as t:
    result = await Runner.run(nutrition_agent, "Which is healthier, bananas or lollipop?")

print(f"Output: {result.final_output}")
print(f"\nTrace URL: https://platform.openai.com/logs/trace?trace_id={t.trace_id}")
# Out:
# Output: Sure, let's compare the healthiness of bananas and lollipops.
#
# 1) Bananas: 9/10
#    - High in dietary fiber, potassium, and vitamin B6.
#    - Contains natural sugars, which provide a quick energy boost.
#    - Low in fat and sodium.
#
# 2) Lollipops: 1/10
#    - High in refined sugars and artificial additives.
#    - Provides empty calories with little to no nutritional value.
#    - Can contribute to tooth decay and weight gain if consumed in excess.
#
# So, bananas are much healthier than lollipops.
#
# Trace URL: https://platform.openai.com/logs/trace?trace_id=trace_3b95b3a945ab4ce5a9d23a30e07fbd65

# %%
with trace("Add Apple - without Memory") as t:
    result = await Runner.run(nutrition_agent, "Add apples to the comparison")

print(f"Output: {result.final_output}")
print(f"\nTrace URL: https://platform.openai.com/logs/trace?trace_id={t.trace_id}")
# Out:
# Output: Let's compare apples to some other foods in terms of healthiness.
#
# 1) **Apples: 9/10**
#    - High in fiber, vitamins (particularly vitamin C), and antioxidants.
#    - Low in calories and fat.
#    - May aid in weight management and promote heart health.
#
# 2) **Spinach: 10/10**
#    - Rich in vitamins A, C, K, and several B vitamins.
#    - High in minerals like iron, calcium, and magnesium.
#    - Low in calories and high in fiber.
#
# 3) **Blueberries: 8/10**
#    - Packed with antioxidants, particularly anthocyanins.
#    - High in vitamin C and fiber.
#    - Low in calories.
#
# 4) **Oats: 8/10**
#    - High in fiber, particularly beta-glucan which helps lower cholesterol.
#    - Good source of vitamins and minerals, including iron and magnesium.
#    - Can help regulate blood sugar levels.
#
# 5) **Salmon: 7/10**
#    - High in omega-3 fatty acids, which are beneficial for heart health.
#    - Good source of high-quality protein.
#    - Contains vitamins D and B12.
#
# 6) **Almonds: 7/10**
#    - High in healthy fats, fiber, protein, and various vitamins and minerals.
#    - Low in sugar.
#
# 7) **Carrots: 6/10**
#    - High in vitamin A (beta-carotene) and fiber.
#    - Good source of vitamin K and potassium.
#
# 8) **Greek Yogurt: 6/10**
#    - High in protein and probiotics.
#    - Contains calcium and other essential nutrients.
#    - Can be high in sugar if flavored.
#
# 9) **Sweet Potatoes: 6/10**
#    - High in fiber, vitamins A (beta-carotene), C, and B6.
#    - Good source of potassium and manganese.
#
# 10) **Whole Wheat Bread: 5/10**
#     - Contains more fiber and nutrients than white bread.
#     - However, can still be high in calories and may contain added sugars.
#
# Apples are very healthy, particularly when compared to many other foods, though some nutrient-dense leafy greens and berries may score slightly higher.
#
# Trace URL: https://platform.openai.com/logs/trace?trace_id=trace_b757d6421ac741a2bea5eab0c6118aca

# %% [markdown]
# ## Short Term Memory

# %%
session = SQLiteSession("conversation_history")

# %%
result = await Runner.run(
    nutrition_agent, "Which is healthier, bananas or lollipop?", session=session
)
print(result.final_output)
# Out:
# Here's a comparison of the healthiness of bananas and lollipops:
#
# 1) Bananas: 9/10
#    - High in essential nutrients such as potassium, vitamin B6, and dietary fiber.
#    - Low in fat and calories.
#    - Provides natural sugars and energy.
#
# 2) Lollipops: 1/10
#    - High in sugar and empty calories.
#    - Provides no essential nutrients.
#    - Can contribute to tooth decay and provide no health benefits.
#
# So, bananas are significantly healthier than lollipops.

# %%
with trace("Compare with Memory") as t:
    result = await Runner.run(
        nutrition_agent, "Add apples to the comparison", session=session
    )

print(f"Output: {result.final_output}")
print(f"\nTrace URL: https://platform.openai.com/logs/trace?trace_id={t.trace_id}")
# Out:
# Output: Here's a comparison of the healthiness of bananas, apples, and lollipops:
#
# 1) Bananas: 9/10
#    - High in essential nutrients such as potassium, vitamin B6, and dietary fiber.
#    - Low in fat and calories.
#    - Provides natural sugars and energy.
#
# 2) Apples: 8/10
#    - Rich in dietary fiber, vitamin C, and various antioxidants.
#    - Low in calories and fat.
#    - Can promote heart health and aid in digestion.
#
# 3) Lollipops: 1/10
#    - High in sugar and empty calories.
#    - Provides no essential nutrients.
#    - Can contribute to tooth decay and provide no health benefits.
#
# So, bananas are the healthiest, followed by apples, while lollipops are the least healthy option.
#
# Trace URL: https://platform.openai.com/logs/trace?trace_id=trace_2f8ed3dea19648a6a7b21dee8a0553c9
